# %%
import rasterio
import rasterio.plot
from rasterio import plot
#import pyproj
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

print('Landsat 8 From USGS:')
file_B4 = 'C:/Users/Reags/g371-env/GEOG371/LC08_L1TP_018030_20200616_20200626_01_T1_B4.TIF'
with rasterio.open(file_B4) as src:
    print(src.profile)
    img4 = src.read(1)
    
plt.figure(figsize=(15,15))
plt.imshow(img4, cmap='gray', vmin=5000, vmax=15000)
plot.colorbar(shrink=0.5)
plt.xlabel('Column #')
plt.ylabel('Row #')
# Out:
# Landsat 8 From USGS:
# {'dtype': 'uint16', 'tiled': False, 'affine': Affine(30.0, 0.0, 456585.0,
#        0.0, -30.0, 4899015.0), 'interleave': 'band', 'transform': (456585.0, 30.0, 0.0, 4899015.0, 0.0, -30.0), 'height': 7851, 'driver': 'GTiff', 'width': 7731, 'count': 1, 'crs': CRS({'init': 'epsg:32617'}), 'nodata': None}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-06fc1e550966> in <module>()
#      15 plt.figure(figsize=(15,15))
#      16 plt.imshow(img4, cmap='gray', vmin=5000, vmax=15000)
# ---> 17 plot.colorbar(shrink=0.5)
#      18 plt.xlabel('Column #')
#      19 plt.ylabel('Row #')
#
# AttributeError: module 'rasterio.plot' has no attribute 'colorbar'
